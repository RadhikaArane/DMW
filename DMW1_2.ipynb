# %%
import pandas as pd     
import numpy as np                 #scientific calculation
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/Country Population Growth Predictions - results-20220831-153501.csv")
#read the dataset

# %%
data.shape
# Out:
# (201, 11)

# %%
data
# Out:
#          Country  Area_km  Population  Pop_Density  Yearly_Change  \
# 0          Macao       30      649335        21645           1.39
# 1      Singapore      700     5850342         8358           0.79
# 2      Hong Kong     1050     7496981         7140           0.82
# 3        Bahrain      760     1701575         2239           3.68
# 4       Maldives      300      540544         1802           1.81
# ..           ...      ...         ...          ...            ...
# 196      Iceland   100250      341243            3           0.65
# 197     Mongolia  1553560     3278290            2           1.65
# 198       Latvia    62200     1886198           30          -1.08
# 199    Lithuania    62674     2722289           43          -1.35
# 200  Puerto Rico     8870     2860853          323          -2.47
#
#      One_Year_Prediction  Density_One_Year  Ten_Year_Prediction  \
# 0                 658361             21945               739593
# ...

# %%
data.isnull().sum()
# Out:
# Country                        0
# Area_km                        0
# Population                     0
# Pop_Density                    0
# Yearly_Change                  0
# One_Year_Prediction            0
# Density_One_Year               0
# Ten_Year_Prediction            0
# Density_Ten_Year               0
# One_Hundred_Year_Prediction    0
# Density_One_Hundred_Year       0
# dtype: int64

# %%
data.isnull().any()
# Out:
# Country                        False
# Area_km                        False
# Population                     False
# Pop_Density                    False
# Yearly_Change                  False
# One_Year_Prediction            False
# Density_One_Year               False
# Ten_Year_Prediction            False
# Density_Ten_Year               False
# One_Hundred_Year_Prediction    False
# Density_One_Hundred_Year       False
# dtype: bool

# %%
data.dropna()
# Out:
#          Country  Area_km  Population  Pop_Density  Yearly_Change  \
# 0          Macao       30      649335        21645           1.39
# 1      Singapore      700     5850342         8358           0.79
# 2      Hong Kong     1050     7496981         7140           0.82
# 3        Bahrain      760     1701575         2239           3.68
# 4       Maldives      300      540544         1802           1.81
# ..           ...      ...         ...          ...            ...
# 196      Iceland   100250      341243            3           0.65
# 197     Mongolia  1553560     3278290            2           1.65
# 198       Latvia    62200     1886198           30          -1.08
# 199    Lithuania    62674     2722289           43          -1.35
# 200  Puerto Rico     8870     2860853          323          -2.47
#
#      One_Year_Prediction  Density_One_Year  Ten_Year_Prediction  \
# 0                 658361             21945               739593
# ...
